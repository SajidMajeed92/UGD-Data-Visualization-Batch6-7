# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.Age.dtype
# Out:
# dtype('float64')

# %%
df.Cabin.dtype
# Out:
# dtype('O')

# %%
df.Embarked.dtype
# Out:
# dtype('O')

# %%
df.Age.mean()
# Out:
# 29.69911764705882

# %%
df.Age.median()
# Out:
# 28.0

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())

# %%
df.Age.unique()
# Out:
# array([22.        , 38.        , 26.        , 35.        , 29.69911765,
#        54.        ,  2.        , 27.        , 14.        ,  4.        ,
#        58.        , 20.        , 39.        , 55.        , 31.        ,
#        34.        , 15.        , 28.        ,  8.        , 19.        ,
#        40.        , 66.        , 42.        , 21.        , 18.        ,
#         3.        ,  7.        , 49.        , 29.        , 65.        ,
#        28.5       ,  5.        , 11.        , 45.        , 17.        ,
#        32.        , 16.        , 25.        ,  0.83      , 30.        ,
#        33.        , 23.        , 24.        , 46.        , 59.        ,
#        71.        , 37.        , 47.        , 14.5       , 70.5       ,
#        32.5       , 12.        ,  9.        , 36.5       , 51.        ,
#        55.5       , 40.5       , 44.        ,  1.        , 61.        ,
#        56.        , 50.        , 36.        , 45.5       , 20.5       ,
# ...

# %%
# df['Age']=df['Age'].ffill()
# df['Age']=df['Age'].bfill()

# %%
df['Age'].unique()
# Out:
# array([22.        , 38.        , 26.        , 35.        , 29.69911765,
#        54.        ,  2.        , 27.        , 14.        ,  4.        ,
#        58.        , 20.        , 39.        , 55.        , 31.        ,
#        34.        , 15.        , 28.        ,  8.        , 19.        ,
#        40.        , 66.        , 42.        , 21.        , 18.        ,
#         3.        ,  7.        , 49.        , 29.        , 65.        ,
#        28.5       ,  5.        , 11.        , 45.        , 17.        ,
#        32.        , 16.        , 25.        ,  0.83      , 30.        ,
#        33.        , 23.        , 24.        , 46.        , 59.        ,
#        71.        , 37.        , 47.        , 14.5       , 70.5       ,
#        32.5       , 12.        ,  9.        , 36.5       , 51.        ,
#        55.5       , 40.5       , 44.        ,  1.        , 61.        ,
#        56.        , 50.        , 36.        , 45.5       , 20.5       ,
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
# Catagorical data ---> mode
df['Embarked']=df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df['Cabin']=df['Cabin'].fillna(df['Cabin'].mode()[0])

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# # Percentage Deaths and Survivors

# %%
# Survived 0 (Death) , 1 (Survived)
no_of_pessengers = df['Survived'].value_counts()
no_of_pessengers
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
no_of_death = no_of_pessengers[0]
no_of_alive = no_of_pessengers[1]

# %%
perc_of_death = (no_of_death/(no_of_death+no_of_alive))*100
print("Percentage of Death: ",perc_of_death)
# Out:
# Percentage of Death:  61.61616161616161

# %%
perc_of_alive = (no_of_alive/(no_of_death+no_of_alive))*100
print("Percentage of Alive:",perc_of_alive)
# Out:
# Percentage of Alive: 38.38383838383838

# %%
# Bar graph
objects=("Number of Death","Number of Survived")
bars=np.arange(len(objects))
no_of_pessengers.plot(kind="bar",figsize=(6,4),color=['g','b'])
plt.xticks(bars,objects,rotation='horizontal')
plt.title("Total Number of Passengers - Deaths and Survived on Titanic")
plt.ylabel("No of Pessengers")
plt.xlabel("Total No of Pessengers")
plt.show()

# %%
# pie chart
colors=['yellowgreen','lightcoral']
labels=['Died','Survived']
plt.pie(no_of_pessengers,colors=colors,labels=labels,autopct='%.2f')
plt.title("Total Number of Passengers - Deaths and Survived on Titanic")
plt.show()

# %% [markdown]
# # Female - Male -- Deaths and Survivors

# %%
male_female=df.groupby('Sex').size()
male_female
# Out:
# Sex
# female    314
# male      577
# dtype: int64

# %%
survived_male_female = df.groupby(['Sex','Survived']).size()
survived_male_female
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# dtype: int64

# %%
colors=['yellow','blue','green','gold']
labels=['Death females',"Survived females",'Death males',"Survived males"]
plt.title('Total Number of Females and Males - Deaths and Survived on Titanic')
plt.pie(survived_male_female,colors=colors,labels=labels,explode=[0.1,0,0,0],autopct='%.2f')
plt.show()

# %%
objects=('Number of Female - Deaths', 'Number of Female - Survivors', 'Number of Male - Deaths', 'Number of Male - Survivors')
bars = np.arange(len(objects))
survived_male_female.plot(kind='bar',figsize=(12,6),color=['red','green','yellow','orange'])
plt.xticks(bars,objects,rotation='horizontal')
plt.ylabel("Number of Passengers")
plt.xlabel("Total Number of Passengers")
plt.title("Total Number of Females and Males - Deaths and Survived on Titanic")
plt.show()

# %% [markdown]
# # Age of Passengers

# %%
passenger_age = df.groupby('Age').size()
passenger_age.unique()
# Out:
# array([  1,   2,   7,  10,   6,   4,   3,   8,   5,  17,  13,  26,  25,
#         15,  24,  27,  30,  23,  18,  20, 177,  22,  11,  14,   9,  12])

# %%
passenger_age.plot(kind='bar',figsize=(15,13),color='r')
plt.title("Distribution of Passenger w.r.t Age")
plt.xlabel("Age of a Passenger")
plt.ylabel("No of Passengers")
plt.show()

# %%
df.Age.describe()
# Out:
# count    891.000000
# mean      29.699118
# std       13.002015
# min        0.420000
# 25%       22.000000
# 50%       29.699118
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# # Number of Passengers Traveling with their Sibling/Spouse

# %%
sibsp_pessengers= df.groupby('SibSp').size()
sibsp_pessengers.unique()
# Out:
# array([608, 209,  28,  16,  18,   5,   7])

# %%
sibsp_pessengers.plot(kind = "bar", figsize = (10,8), color = ['red','green','yellow','orange','gold','blue','black','pink','purple'])
plt.ylabel("Number of Passengers")
plt.xlabel("Number of Siblings/Spouse")
plt.title("Number of Passengers Traveling with their Sibling/Spouse")
plt.show()

# %% [markdown]
# # Number of Passengers traveling with their Parents/Children

# %%
parch_passengers=df.groupby('Parch').size()
parch_passengers
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 3      5
# 4      4
# 5      5
# 6      1
# dtype: int64

# %%
parch_passengers.unique()
# Out:
# array([678, 118,  80,   5,   4,   1])

# %%
parch_passengers.plot(kind='bar',figsize=(10,8),color='c')
plt.ylabel("Number of Passengers")
plt.xlabel("Number of Parents/Children")
plt.title("Number of Passengers traveling with their Parents/Children")
plt.show()

# %% [markdown]
# # Number of Passengers w.r.t to Gender Traveling in Different Socio-Economic Classes

# %%
pclass_passengers=df.groupby(['Sex','Pclass']).size()
pclass_passengers
# Out:
# Sex     Pclass
# female  1          94
#         2          76
#         3         144
# male    1         122
#         2         108
#         3         347
# dtype: int64

# %%
objects=("Female in Class P-1","Female in Class P-2","Female in Class P-3","Male in Class P-1","Male in Class P-2","Male in Class P-3")
bars=np.arange(len(objects))
pclass_passengers.plot(kind='bar',figsize=(12,10),color='g')
plt.xticks(bars,objects,rotation='horizontal')
plt.ylabel("Number of Passengers")
plt.xlabel("Number of Passenger Class")
plt.title("Number of Passengers traveling in Class")
plt.show()

# %%
colors=['red','green','yellow','orange','gold','blue']
labels=["Female in Class P-1","Female in Class P-2","Female in Class P-3","Male in Class P-1","Male in Class P-2","Male in Class P-3"]
plt.pie(pclass_passengers,colors=colors,labels=labels,autopct='%.2f',explode=[0,0.1,0,0,0,0])
plt.title("Number of Passengers traveling in Class")
plt.show()

# %% [markdown]
# # Number of Passengers Traveling in Class 1, 2, 3 - Deaths and Survivors

# %%
pessenger_survival_class = df.groupby(['Pclass','Survived']).size()
pessenger_survival_class
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# dtype: int64

# %%
colors=['red','green','yellow','orange','gold','blue']
labels=["Death in Class P-1","Death in Class P-2","Death in Class P-3","Survived in Class P-1","Survived in Class P-2","Survived in Class P-3"]
plt.pie(pessenger_survival_class,colors=colors,labels=labels,autopct='%.2f',explode=[0,0.1,0,0,0,0])
plt.title("Number of Death & Survived Passengers traveling in Class")
plt.show()

# %%
objects=("Death in Class P-1","Death in Class P-2","Death in Class P-3","Survived in Class P-1","Survived in Class P-2","Survived in Class P-3")
bars=np.arange(len(objects))
pessenger_survival_class.plot(kind='bar',figsize=(12,10),color=['red','green','yellow','orange','gold','blue'])
plt.xticks(bars,objects,rotation='horizontal')
plt.ylabel("Number of Passengers")
plt.xlabel("Number of Death & Survived Passenger Class")
plt.title("Number of Death & Survived Passengers traveling in Class")
plt.show()

# %%
gender_survived_passengers =  df.groupby(['Pclass','Survived','Sex']).size()
gender_survived_passengers
# Out:
# Pclass  Survived  Sex
# 1       0         female      3
#                   male       77
#         1         female     91
#                   male       45
# 2       0         female      6
#                   male       91
#         1         female     70
#                   male       17
# 3       0         female     72
#                   male      300
#         1         female     72
#                   male       47
# dtype: int64

# %%
objects = ("Class-1 Death Female","Class-2 Death Female","Class-3 Death Female","Class-1 Death Male","Class-2 Death Male","Class-3 Death Male","Class-1 Survived Female","Class-2 Survived Female","Class-3 Survived Female","Class-1 Survived Male","Class-2 Survived Male","Class-3 Survived Male")
bars = np.arange(len(objects))
gender_survived_passengers.plot(kind='bar',figsize=(26,12),color=['red','green','yellow','orange','gold','blue'])
plt.xticks(bars,objects,rotation='horizontal')
plt.ylabel("Number of Passengers")
plt.xlabel("Number of Death & Survived Passenger Class")
plt.title("Number of Death & Survived Passengers traveling in Class")
plt.show()

# %%
import matplotlib as mpl
mpl.rcParams['font.size'] = 9.0
colors=['red','green','yellow','orange','gold','blue']
labels=["C-1 Death Female","C-2 Death Female","C-3 Death Female","C-1 Death Male","C-2 Death Male","C-3 Death Male","C-1 Survived Female","C-2 Survived Female","C-3 Survived Female","C-1 Survived Male","C-2 Survived Male","C-3 Survived Male"]
plt.pie(gender_survived_passengers,colors=colors,labels=labels,autopct='%.2f')
plt.title("Number of Death & Survived Passengers traveling in Class")
plt.show()

# %%
import seaborn as sns
# Box Plot of Survivors from Pclass v/s Fare
sns.boxplot(x='Pclass',y='Fare',hue='Survived',data=df,palette = "Set1", width = 0.7, fliersize = 3, whis = 1.5, linewidth = 0.5)
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
# Number of Passengers that Died and Survived with respect to the Fare
pessenger_survived_fare = df.groupby(['Survived','Fare']).size()
pessenger_survived_fare
# Out:
# Survived  Fare
# 0         0.0000      14
#           4.0125       1
#           5.0000       1
#           6.2375       1
#           6.4375       1
#                       ..
# 1         227.5250     3
#           247.5208     1
#           262.3750     2
#           263.0000     2
#           512.3292     3
# Length: 330, dtype: int64

# %%
ax = sns.boxplot(x = "Survived", y = "Fare",data = df, palette = "Set1", width = 0.7, fliersize = 3, whis = 1.5, linewidth = 0.5)
plt.title("Number of Passengers that Died and Survived with respect to the Fare")
plt.legend(["Dead (Red)","Survived (Blue)"])
plt.show()
# Out:
# <ipython-input-73-f2be462df1e6>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x = "Survived", y = "Fare",data = df, palette = "Set1", width = 0.7, fliersize = 3, whis = 1.5, linewidth = 0.5)

# %%
sns.violinplot(hue='Survived',y='Fare',data=df,palette = "Set1", linewidth = 0.5)
plt.show()

# %%
df['Cabin_deck']=df['Cabin'].astype(str).str[0]

# %%
df['Cabin_deck'].unique()
# Out:
# array(['B', 'C', 'E', 'G', 'D', 'A', 'F', 'T'], dtype=object)

# %%
Cabin_deck = df.groupby('Cabin_deck').size()
Cabin_deck
# Out:
# Cabin_deck
# A     15
# B    734
# C     59
# D     33
# E     32
# F     13
# G      4
# T      1
# dtype: int64

# %%
# Distribution of Deck (Cabin) and Survived
deck_survived = df.groupby(['Survived','Cabin_deck']).size()
deck_survived
# Out:
# Survived  Cabin_deck
# 0         A               8
#           B             493
#           C              24
#           D               8
#           E               8
#           F               5
#           G               2
#           T               1
# 1         A               7
#           B             241
#           C              35
#           D              25
#           E              24
#           F               8
#           G               2
# dtype: int64

# %%
objects=('A0','B0','C0','D0','E0','F0','G0','T0','A1','B1','C1','D1','E1','F1','G1','T1')
bars = np.arange(len(objects))
deck_survived.plot(kind = "bar", figsize = (10,8))
plt.xticks(bars,objects,rotation='horizontal')
plt.ylabel("Number of Passengers")
plt.xlabel("Cabin Deck")
plt.title("Distribution of Survivors and Deaths with respect to Deck")
plt.legend(['Died', 'Survived'])
plt.show()
